# %%
pip install arxiv
# Out:
# ...
#      |████████████████████████████████| 194kB 4.9MB/s
# ...
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=ffc0acd94ea155f7805e94db3e9574c9eee70de4584cc8adaa7059cb1717fd11
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
# Successfully built feedparser
# ...

# %%
import arxiv

# %%
res=arxiv.query(query="cs.AI",
            id_list=[],
            max_results=2,
            start = 0,
            sort_by="relevance",
            sort_order="descending",
            prune=True,
            iterative=False,
            )

# %%
res
# Out:
# [{'affiliation': 'None',
#   'arxiv_comment': None,
#   'arxiv_primary_category': {'scheme': 'http://arxiv.org/schemas/atom',
#    'term': 'cs.AI'},
#   'arxiv_url': 'http://arxiv.org/abs/1511.04326v1',
#   'author': 'Lars Kotthoff',
#   'author_detail': {'name': 'Lars Kotthoff'},
#   'authors': ['Lars Kotthoff'],
#   'doi': None,
#   'guidislink': True,
#   'id': 'http://arxiv.org/abs/1511.04326v1',
#   'journal_reference': None,
#   'links': [{'href': 'http://arxiv.org/abs/1511.04326v1',
#     'rel': 'alternate',
#     'type': 'text/html'},
#    {'href': 'http://arxiv.org/pdf/1511.04326v1',
#     'rel': 'related',
#     'title': 'pdf',
#     'type': 'application/pdf'}],
#   'pdf_url': 'http://arxiv.org/pdf/1511.04326v1',
#   'published': '2015-11-12T20:04:31Z',
#   'published_parsed': time.struct_time(tm_year=2015, tm_mon=11, tm_mday=12, tm_hour=20, tm_min=4, tm_sec=31, tm_wday=3, tm_yday=316, tm_isdst=0),
# ...

# %%
arxiv.download(obj, dirpath="/content/sample_data", slugify=arxiv.slugify)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-282831fcd6a5> in <module>()
# ----> 1 arxiv.download(obj, dirpath="/content/sample_data", slugify=arxiv.slugify)
#
# NameError: name 'obj' is not defined

# %%
import arxiv
# Query for a paper of interest, then download
paper = arxiv.query(id_list=["1707.08567"])[0]
arxiv.download(paper)
# Out:
# './1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf'

# %%
pip install PyPDF2
# Out:
# ...
#      |████████████████████████████████| 81kB 2.4MB/s
# ...
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp36-none-any.whl size=61085 sha256=f01c86b2a59ba02dcd8c409b3983654f2a66a8ace81e1066347fffa93903c808
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# ...

# %%
pip install textract
# Out:
# ...
#      |████████████████████████████████| 51kB 2.5MB/s
# ...
#      |████████████████████████████████| 8.9MB 10.2MB/s
# ...
#      |████████████████████████████████| 5.6MB 38.6MB/s
# ...
#      |████████████████████████████████| 112kB 49.9MB/s
# ...
#      |████████████████████████████████| 32.8MB 69kB/s
# ...
#      |████████████████████████████████| 102kB 9.6MB/s
# ...
#      |████████████████████████████████| 112kB 56.1MB/s
# ...
#      |████████████████████████████████| 81kB 6.5MB/s
# ...
#      |████████████████████████████████| 143kB 45.4MB/s
# ...
#      |████████████████████████████████| 9.7MB 36.3MB/s
# ...
#   Created wheel for python-pptx: filename=python_pptx-0.6.18-cp36-none-any.whl size=275707 sha256=fe4980987b02fb46a2b732b5667c9047adaa55aec6d8cb6b685d5467cf1103d1
#   Stored in directory: /root/.cache/pip/wheels/1f/1f/2c/29acca422b420a0b5210bd2cd7e9669804520d602d2462f20b
# ...
#   Created wheel for EbookLib: filename=EbookLib-0.17.1-cp36-none-any.whl size=38164 sha256=227150313db049beefff2671a62ca4e4692e13bd0031c7beb6e44fe0e1115bc6
# ...

# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-4e7f2691d9ff> in <module>()
# ----> 1 import PyPDF2
#       2 import textract
#       3 from nltk.tokenize import word_tokenize
#       4 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'PyPDF2'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
 import nltk
 nltk.download('punkt')
 nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
filename='/content/1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf'
pdfFileObj = open(filename,'rb')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
num_pages = pdfReader.numPages
count = 0
text = ""
while count < num_pages:
    pageObj = pdfReader.getPage(count)
    count +=1
    text += pageObj.extractText()

    
pdfFileObj.close()

# %%
from PyPDF2 import PdfFileReader
def extract_information(pdf_path):
    with open(pdf_path, 'rb') as f:
        pdf = PdfFileReader(f)
        information = pdf.getDocumentInfo()
        number_of_pages = pdf.getNumPages()

# %%
from PyPDF2 import PdfFileReader
text=extract_information(filename)

# %%
text

# %%
    pdf_document_writer = PyPDF2.PdfFileWriter()
    pdf_document_writer.addPage(pageObj)
    pdf_output_file = open('new_pdf_file.pdf', 'wb')
    pdf_document_writer.write(pdf_output_file)

# %%
filename='/content/1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf'
pdfFileObj = open(filename,'r+b')
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
num_pages = pdfReader.numPages
count = 0
text = ""
for page in range(pdfReader.numPages):
        pageObj = pdfReader.getPage(page)
        pdf_document_writer = PyPDF2.PdfFileWriter()
        pdf_document_writer.addPage(pageObj)
        pdf_output_file = open('new_pdf_file.pdf', 'wb')
        pdf_document_writer.write('/contents/sample.pdf')

# %%
tokens = word_tokenize(text)

# %%
stop_words = stopwords.words('english')

# %%
punctuations = ['(',')',';',':','[',']',',']
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
filename='/content/1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf'
pdfFileObj = open(filename,'rb')

# %%
data=pdfFileObj.read()

# %%
s=str(data)

# %%
s.encode('utf-8')

# %%
data.decode('en')

# %%
pip install pdfminer.six

# %%
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, 'utf-8', LAParams())
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages, password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

# %%
convert_pdf_to_txt('/content/1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf')

# %%
pip install tika
# Out:
# ...
#   Created wheel for tika: filename=tika-1.22-cp36-none-any.whl size=30410 sha256=a974025634dd2d78cd718478ead78991712d40200287fa7fe5c4a7b4a36e1b61
#   Stored in directory: /root/.cache/pip/wheels/76/9d/c5/be9d60fca685060535e2e9635a42f77abc0d520c0eed98fcfd
# Successfully built tika
# ...

# %%
from tika import parser
raw=parser.from_file('/content/1707.08567v1.Proceedings_of_Workshop_AEW10_Concepts_in_Information_Theory_and_Communications.pdf')
s=raw['content']

# %%
raw=raw.encode('ascii',errors='replace')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-440bbd2d1dd6> in <module>()
# ----> 1 raw=raw.encode('ascii',errors='replace')
#
# AttributeError: 'dict' object has no attribute 'encode'

# %%
raw=raw.decode('ascii')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-32eeaeb0e49b> in <module>()
# ----> 1 raw=raw.decode('ascii')
#
# AttributeError: 'dict' object has no attribute 'decode'

# %%
raw
# Out:
# {'content': '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n(AEW10_Proceedings)\n\n\n!"#$%%&\'()*+#,+-#".*/#0+12-34\n\n56(%+73879:+743;:+<#00="&:+>%"?=(@\n\n34A/ 1*\'=826"#0%+-#".*/#0+#(\n\nB#($%0A*+\'(+C(,#"?=A\'#(+D/%#"@+=(&+B#??6(\'$=A\'#(*\n\nE0#(*#"%&+F@\n\nTURING MACHINES INC.\n\n!"#$%&\'()"(*"+%$*,\'-)"./0/0*(*\n\nGermany Chapter on Information Theory.\n\nBenelux Working Community on Information Theory.\n\n!\n\n! ! !\n\n\n\n\n\n\n\n\n\n!"#$%%&\'()*+#,+-#".*/#0+12-34\n\n56(%+73879:+743;:+<#00="&:+>%"?=(@\n\n34A/ 1*\'=826"#0%+-#".*/#0+#(\n\nB#($%0A*+\'(+C(,#"?=A\'#(+D/%#"@+=(&+B#??6(\'$=A\'#(*\n\nE0#(*#"%&+F@\n\nTURING MACHINES INC.\n\n!"#$%&\'()"(*"+%$*,\'-)"./0/0*(*\n\nGermany Chapter on Information Theory.\n\nBenelux Working Community on Information Theory.\n\n\n\n \n\n \n\n \n\n \n\nISBN/EAN:  978-90-74249-29-4 \n\nTitel:   Proceedings of Workshop AEW10 Concepts in Information \n\nTheory and Communications   \n\nAuteur:   Chen, Yanling / 
# ...

# %%
content=raw['content']

# %%
author=raw['metadata']['Author']

# %%
title=raw['metadata']['title']

# %%
author
# Out:
# '(Yanling Chen)'

# %% [markdown]
# **Text Cleaning**

# %%
import re

# %%
author=author[1:len(author)-1]

# %%
title=title[1:len(title)-1]

# %%
content
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n(AEW10_Proceedings)\n\n\n!"#$%%&\'()*+#,+-#".*/#0+12-34\n\n56(%+73879:+743;:+<#00="&:+>%"?=(@\n\n34A/ 1*\'=826"#0%+-#".*/#0+#(\n\nB#($%0A*+\'(+C(,#"?=A\'#(+D/%#"@+=(&+B#??6(\'$=A\'#(*\n\nE0#(*#"%&+F@\n\nTURING MACHINES INC.\n\n!"#$%&\'()"(*"+%$*,\'-)"./0/0*(*\n\nGermany Chapter on Information Theory.\n\nBenelux Working Community on Information Theory.\n\n!\n\n! ! !\n\n\n\n\n\n\n\n\n\n!"#$%%&\'()*+#,+-#".*/#0+12-34\n\n56(%+73879:+743;:+<#00="&:+>%"?=(@\n\n34A/ 1*\'=826"#0%+-#".*/#0+#(\n\nB#($%0A*+\'(+C(,#"?=A\'#(+D/%#"@+=(&+B#??6(\'$=A\'#(*\n\nE0#(*#"%&+F@\n\nTURING MACHINES INC.\n\n!"#$%&\'()"(*"+%$*,\'-)"./0/0*(*\n\nGermany Chapter on Information Theory.\n\nBenelux Working Community on Information Theory.\n\n\n\n \n\n \n\n \n\n \n\nISBN/EAN:  978-90-74249-29-4 \n\nTitel:   Proceedings of Workshop AEW10 Concepts in Information \n\nTheory and Communications   \n\nAuteur:   Chen, Yanling / Vinck, A.J. 
# ...

# %%
import nltk

# %%
import re, string
txt= open("uH3h7NAk.txt", "r+")
txt=txt.read()#Reading
txt=str(txt.encode(encoding = 'UTF-8',errors = 'strict')) #UTF-8 Encoding
clean = re.sub(r"[0-9,.;@#?!&$]+\ *", " ", txt)  #Removes unncessary stuff for word vectors
s=clean
exclude = set(string.punctuation)
table = str.maketrans("","")
regex = re.compile('[%s]' % re.escape(string.punctuation)) #Punctuations
def test_re(s): 
    return regex.sub('', s)
text=test_re(clean)
import nltk
from nltk.corpus import stopwords  #Stop Words influencing the game
cachedStopWords = stopwords.words("english")
text = '  '.join([word for word in text.split() if word not in cachedStopWords]).lower()

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
clean = re.sub(r"[0-9,.,*,@]", " ", content)

# %%
print(clean)
# Out:
# (AEW  _Proceedings)
#
#
# !"#$%%&'() +# +-#"  /# +  -
#
#   (%+     :+   ;:+<#  ="&:+>%"?=(
#
#   A/   '=   "# %+-#"  /# +#(
#
# B#($% A +'(+C( #"?=A'#(+D/%#" +=(&+B#?? ('$=A'#(
#
# E #( #"%&+F
#
# TURING MACHINES INC
#
# !"#$%&'()"( "+%$  '-)" / /  (
#
# Germany Chapter on Information Theory
#
# Benelux Working Community on Information Theory
#
# !
#
# ! ! !
#
#
#
#
#
#
#
#
#
# !"#$%%&'() +# +-#"  /# +  -
#
#   (%+     :+   ;:+<#  ="&:+>%"?=(
#
#   A/   '=   "# %+-#"  /# +#(
#
# B#($% A +'(+C( #"?=A'#(+D/%#" +=(&+B#?? ('$=A'#(
#
# E #( #"%&+F
#
# TURING MACHINES INC
#
# !"#$%&'()"( "+%$  '-)" / /  (
#
# Germany Chapter on Information Theory
#
# Benelux Working Community on Information Theory
#
#
#
#
#
#
#
#
#
#
#
# ISBN/EAN:     -  -     -  -
#
# Titel:   Proceedings of Workshop AEW   Concepts in Information
#
# Theory and Communications
#
# Auteur:   Chen  Yanling / Vinck  A J  Han
#
# Uitgever:  Shannon  Stichting
#
# Bibliografische imprint: Shannon  Stichting
#
# NUR-code:
#
# ...
